# %%
import requests
req=requests.get("https://www.kaggle.com")
webpage=req.text
print(webpage)
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#   <title>Kaggle: Your Machine Learning and Data Science Community</title>
#   <meta charset="utf-8" />
#     <meta name="robots" content="index, follow" />
#   <meta name="description" content="Kaggle is the world&#x2019;s largest data science community with powerful tools and resources to help you achieve your data science goals." />
#   <meta name="turbolinks-cache-control" content="no-cache" />
#     <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0">
#   <meta name="theme-color" content="#008ABC" />
#   <script nonce="93pyKPAqbj3/3Xu83UPwXA==" type="text/javascript">
#     window["pageRequestStartTime"] = 1702497964585;
#     window["pageRequestEndTime"] = 1702497964593;
#     window["initialPageLoadStartTime"] = new Date().getTime();
#   </script>
# ...

# %%
# Testing Automated Navigation

from selenium import webdriver
from selenium.webdriver.firefox.service import Service
import time
import random

driver_path = 'C:\\geckodriver-v0.33.0-win64\\geckodriver.exe'
service = Service(executable_path=driver_path)
driver = webdriver.Firefox(service=service)

try:
    
    search_url = 'https://www.kaggle.com/search?q=telecom+customer+churn'
    driver.get(search_url)
    time.sleep(random.uniform(3, 7))  # Random wait

    
    print("Current URL:", driver.current_url)

except Exception as e:
    print("Error occurred:", e)

finally:
    driver.quit()
# Out:
# Current URL: https://www.kaggle.com/search?q=telecom+customer+churn

# %%
import random
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.firefox.service import Service
import time

def random_sleep(min_seconds, max_seconds):
    """ Sleep for a random interval between min_seconds and max_seconds """
    time.sleep(random.uniform(min_seconds, max_seconds))

# Set the path for the Geckodriver
driver_path = 'C:\\geckodriver-v0.33.0-win64\\geckodriver.exe'

# Start the Firefox browser
service = Service(driver_path)
driver = webdriver.Firefox(service=service)

# Open the Kaggle login page
driver.get("https://www.kaggle.com/account/login")

# Random sleep
random_sleep(2, 5)

# Enter username
username_input = driver.find_element_by_id("username")
username_input.send_keys("your_username")  # Replace with your username

# Enter password
password_input = driver.find_element_by_id("password")
password_input.send_keys("your_password")  # Replace with your password

# Click the login button
login_button = driver.find_element_by_xpath("//button[@type='submit']")
login_button.click()

# Wait for the login process to complete
random_sleep(3, 7)

# Now search for the dataset
search_box = driver.find_element_by_css_selector('input[data-testid="search-input-bar"]')
search_box.send_keys("telecom customer churn datasets")
search_box.send_keys(Keys.ENTER)

# Random sleep while waiting for search results to load
random_sleep(3, 7)

# Print the current URL
print("Current URL after search:", driver.current_url)


# Close the browser
driver.quit()
